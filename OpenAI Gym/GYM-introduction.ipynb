# %% [markdown]
# # Gym introduction (coursera-Advanced-Machine-Learning-specialization)

# %%
import gym
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
env = gym.make("MountainCar-v0")
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)
# Out:
# Observation space: Box(2,)
# Action space: Discrete(3)

# %%
plt.imshow(env.render('rgb_array'))

# %%
obs0 = env.reset()
print("initial observation code:", obs0)
# Out:
# initial observation code: [-0.52453658  0.        ]

# %%
-0.46943224 <  0.46883671
# Out:
# True

# %%
print("taking action 2 (right)")
new_obs, reward, is_done, _ = env.step(2)

print("new observation code:", new_obs)
print("reward:", reward)
print("is game over?:", is_done)

# Note: as you can see, the car has moved to the riht slightly (around 0.0005)
# Out:
# taking action 2 (right)
# new observation code: [-0.52352955  0.00100703]
# reward: -1.0
# is game over?: False

# %%
observation = env.reset()
new_obs, reward, is_done, _ = env.step(0)
print(observation[0])
# Out:
# -0.422443817915

# %%
# create env manually to set time limit. Please don't change this.
TIME_LIMIT = 250
env = gym.wrappers.TimeLimit(gym.envs.classic_control.MountainCarEnv(),
                             max_episode_steps=TIME_LIMIT + 1)
s = env.reset()
actions = {'left': 0, 'stop': 1, 'right': 2}

# prepare "display"
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

def policy(t):
    if t > 45:
        return actions['right']
    else:
        return actions['left']

for t in range(TIME_LIMIT):
    
    # change the line below to reach the flag
    s, r, done, _ = env.step(policy(t))
    
    #draw game image on display
    ax.clear()
    ax.imshow(env.render('rgb_array'))
    fig.canvas.draw()
    print(s[0])
    if done:
        print("Well done!")
        break
else:    
    print("Time limit exceeded. Try again.")
# Out:
# <img src="data:image/png;base64,..." width="432">
# -0.427847290869
# -0.431276258846
# -0.436388826897
# -0.443148033141
# -0.45150477908
# -0.461398024335
# -0.472755072615
# -0.485491971742
# -0.499514049774
# -0.514716606118
# -0.53098577085
# -0.548199537652
# -0.566228966187
# -0.584939539154
# -0.604192648572
# -0.623847175983
# -0.643761123289
# -0.663793245561
# -0.683804635111
# -0.703660207469
# -0.723230044691
# -0.742390559043
# -0.761025449931
# -0.779026437924
# -0.796293771037
# -0.812736509082
# -0.828272601265
# -0.842828779665
# -0.856340296666
# -0.8687505377
# -0.880010541978
# -0.890078463514
# -0.898919003097
# -0.906502839177
# -0.912806082432
# -0.917809775229
# -0.921499453574
# -0.923864785669
# -0.924899297861
# -0.924600195673
# -0.922968284747
# -0.920007993748
# -0.915727498648
# -0.910138945097
# -0.903258762805
# -0.89510806286
# -0.883713105757
# -0.869112850114
# -0.851360972774
# -0.830528286466
# -0.806705402454
# -0.780005440031
# -0.750566539979
# -0.718553902069
# -0.684161046302
# -0.647610003756
# -0.609150184353
# -0.569055750459
# -0.527621444977
# -0.485156970207
# -0.441980170309
# -0.398409411521
# -0.354755655444
# -0.311314762694
# -0.268360538745
# -0.226138945799
# -0.184863770916
# -0.144713885345
# -0.105832078331
# -0.0683253214243
# -0.0322662292104
# 0.00230456634336
# 0.0353754216459
# 0.06696034222
# 0.0970955348827
# 0.125836039608
# 0.15325257923
# 0.179428718795
# 0.204458386935
# 0.228443780492
# 0.251493650614
# 0.273721952879
# 0.295246834317
# 0.31618992515
# 0.336675901331
# 0.356832284361
# 0.376789446565
# 0.39668079215
# 0.416643086407
# 0.43681690693
# 0.457347191136
# 0.478383853462
# 0.50008244283
# Well done!
